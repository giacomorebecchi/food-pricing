# %%
import dask.dataframe as dd
from src.data.storage import get_local_data_path

# %%
file_path_coordinates = get_local_data_path(
    path=["external", "geopy"],
    file_name="coordinates",
    file_format=".parquet",
)

ddf_coordinates = dd.read_parquet(file_path_coordinates)
ddf_coordinates.head()
# Out:
#                 city               zone        lat        lon
# 0              cuneo              cuneo  44.458070   7.558137
# 1      lamezia-terme      lamezia-terme  38.964507  16.302145
# 2  montecatini-terme  montecatini-terme  43.883179  10.770953
# 3            sanremo            sanremo  43.819825   7.774883
# 4            tortona            tortona  44.896660   8.864128

# %%
file_path_stores = get_local_data_path(
    path=["interim", "store"],
)
ddf_stores = dd.read_parquet(file_path_stores)
ddf_stores.head()
# Out:
# /home/giacomorebecchi/mambaforge/envs/food-pricing/lib/python3.9/site-packages/dask/dataframe/core.py:7480: UserWarning: Insufficient elements for `head`. 5 elements requested, only 2 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(
#        id         name  hasOrderNotes tipMessage  menuDisabled  \
# 0  414349  Happy Pizza          False        nan          True
# 0  276784  Pony Burger          False        nan          True
#
#    deliversToCustomerLocation   menuId                                 drnId  \
# 0                       False  1919033  e5ee91da-0472-40a5-9525-e9ea6744d65d
# 0                       False   391036  906f63a0-0d73-47ed-9c93-35f2236bc73b
#
#   currencyCode currencySymbol  ...                 location_address_address1  \
# 0          EUR              €  ...              Via Reich 62, Bergamo, 24020
# 0          EUR              €  ...  Via Agostino Gemelli, 17, Bergamo, 24124
#
# ...

# %%
file_path_menus = get_local_data_path(
    path=["interim", "menu"],
)
ddf_menus = dd.read_parquet(file_path_menus)
ddf_menus.head()
# Out:
#   percentageDiscounted                              name  popular  categoryId  \
# 0                  nan             Panino kebab e bibita    False   138580330
# 1                  nan   Panino kebab, bibita e patatine     True   138580330
# 2                  nan            Piadina kebab e bibita    False   138580330
# 3                  nan  Piadina kebab, bibita e patatine    False   138580330
# 4                  nan             Piatto kebab e bibita    False   138580330
#
#   modifierGroupIds priceDiscounted  isSignatureExclusive productInformation  \
# 0    ['974463437']             nan                 False                nan
# 1    ['974463437']             nan                 False                nan
# 2    ['974463437']             nan                 False                nan
# 3    ['974463437']             nan                 False                nan
# 4    ['974463437']             nan                 False                nan
#
# ...

# %%
file_path_images = get_local_data_path(
    path=["interim", "images"],
)
ddf_images = dd.read_parquet(file_path_images)
ddf_images.head()
# Out:
#                                              imgPath        store  menuRow  \
# 0  food-delivery-crawler/data/images/deliveroo.it...  pony-burger        0
# 1  food-delivery-crawler/data/images/deliveroo.it...  pony-burger        1
# 2  food-delivery-crawler/data/images/deliveroo.it...  pony-burger       10
# 3  food-delivery-crawler/data/images/deliveroo.it...  pony-burger       11
# 4  food-delivery-crawler/data/images/deliveroo.it...  pony-burger       12
#
#   format     city             zone
# 0  .jpeg  bergamo  alzano-lombardo
# 1  .jpeg  bergamo  alzano-lombardo
# 2  .jpeg  bergamo  alzano-lombardo
# 3  .jpeg  bergamo  alzano-lombardo
# 4  .jpeg  bergamo  alzano-lombardo

# %%
file_path_dataset = get_local_data_path(
    path=["processed"],
    file_name="dataset",
    file_format=".parquet"
)
ddf_dataset = dd.read_parquet(file_path_dataset)
ddf_dataset.head()
# Out:
# /home/giacomorebecchi/mambaforge/envs/food-pricing/lib/python3.9/site-packages/dask/dataframe/core.py:7480: UserWarning: Insufficient elements for `head`. 5 elements requested, only 4 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(
#                        name  \
# 54  Panino falafel e bibita
# 55        Focaccia al crudo
# 56     Acqua frizzante 50cl
# 57             Avocado bomb
#
#                                           description  price_fractional  \
# 54                                                nan             650.0
# 55               Crudo di Parma, olio di oliva e sale             650.0
# 56                                                nan             100.0
# 57  Burger di verdure verdi (cavolo riccio, brocco...             900.0
#
#     menuRow                store        lat       lon  \
# 54        6  happy-pizza-bergamo  45.733603  9.730494
# 55      108  happy-pizza-bergamo  45.733603  9.730494
# ...
